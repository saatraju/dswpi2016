# %%
import sys
import jsonpickle
import os
from tweepy import OAuthHandler
import tweepy
import io
def oauth_me():    
    CONSUMER_KEY = 'Y8PpyLf5UW0LSCdwTXHXI8Ypn'
    CONSUMER_SECRET ='BppAOhd8pLJxchOufdS3TTcv3F4CZptnUUHLtW65vsjv7oaJdl'
    OAUTH_TOKEN = '276846978-P2rWU1Dqthv3IRIP3sspbVCyhdmVrVrYqYVuqE1R'
    OAUTH_TOKEN_SECRET = 'ToLp2UEfMDIa9U8Z96g7wwjgS0bno1TxZhE8bpuitCO99'

    
    #OAuth with tweepy wrappers.
    auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
    
    # Construct the API instance
    api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
    print api
    return api


searchQuery = 'RIP'  # 
maxTweets =15000# 
tweetlimit = 100  # 
fName = 'RIP.json' # 
sinceId = "2015-09-01"
untiL = "2016-09-07"


def write_to_json(new_tweets, fName):
    with open(fName, 'a') as datafile:
        for tweet in new_tweets:
            datafile.write(jsonpickle.encode(tweet._json, unpicklable=False) + '\n')

fetched_tweetCount=0
def search_tweet():
    api = oauth_me()
    switch = 0
    while switch < 4:
        num = 0
        if switch == 0:
            searchQuery = 'RIP'
            fName = 'RIP.json'
        elif switch == 1:
            searchQuery = 'R.I.P'
            fName = 'R_I_P.json'
        elif switch == 2:
            searchQuery = 'rest in peace'
            fName = 'restInPeace.json'
        elif switch == 3:
            searchQuery = 'condolence'
            fName = 'condolence.json'
        switch += 1    
        while num < 6:
            fetched_tweetCount = 0
            if num == 0:
                sinceId = "2016-02-01"
                untiL = "2016-02-02"
            elif num == 1:
                sinceId = "2016-02-02"
                untiL = "2016-02-03"
            elif num == 2:
                sinceId = "2016-02-03"
                untiL = "2016-02-04"
            elif num == 3:
                sinceId = "2016-02-04"
                untiL = "2016-02-05"
            elif num == 4:
                sinceId = "2016-02-05"
                untiL = "2016-02-06"
            elif num == 5:
                sinceId = "2016-02-06"
                untiL = "2016-02-07"
                
            print "Start Date: {0}".format(sinceId)
            print "End Date: {0}".format(untiL)
            while fetched_tweetCount < maxTweets:
                try:
                    new_tweets = api.search(q=searchQuery, count=tweetlimit, since=sinceId, until = untiL)
                    if not new_tweets:
                        print "No more tweets found" 
                        break
                    write_to_json(new_tweets, fName)
                    fetched_tweetCount += len(new_tweets)
                    print "fetched_tweetCount : {0}".format(fetched_tweetCount)
                    max_id = new_tweets[-1].id
                except tweepy.TweepError as e:
                    # Just exit if any error
                    print "ERROR - " + str(e)
                    break 
            num += 1


search_tweet()
print ("Total tweets {0}".format(fetched_tweetCount))
# Out:
# <tweepy.api.API object at 0x000000000451C080>
# Start Date: 2016-02-01
# End Date: 2016-02-02
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-02
# End Date: 2016-02-03
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# Rate limit reached. Sleeping for: 293
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-03
# End Date: 2016-02-04
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# Rate limit reached. Sleeping for: 688
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-04
# End Date: 2016-02-05
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# Rate limit reached. Sleeping for: 700
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-05
# End Date: 2016-02-06
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# Rate limit reached. Sleeping for: 677
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-06
# End Date: 2016-02-07
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-01
# End Date: 2016-02-02
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# Rate limit reached. Sleeping for: 662
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-02
# End Date: 2016-02-03
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# Rate limit reached. Sleeping for: 698
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-03
# End Date: 2016-02-04
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# Rate limit reached. Sleeping for: 600
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-04
# End Date: 2016-02-05
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-05
# End Date: 2016-02-06
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# Rate limit reached. Sleeping for: 658
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-06
# End Date: 2016-02-07
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# Rate limit reached. Sleeping for: 656
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# ...
# fetched_tweetCount : 6080
# fetched_tweetCount : 6175
# fetched_tweetCount : 6270
# fetched_tweetCount : 6365
# fetched_tweetCount : 6460
# fetched_tweetCount : 6555
# fetched_tweetCount : 6650
# fetched_tweetCount : 6745
# fetched_tweetCount : 6840
# fetched_tweetCount : 6935
# fetched_tweetCount : 7030
# fetched_tweetCount : 7125
# fetched_tweetCount : 7220
# fetched_tweetCount : 7315
# fetched_tweetCount : 7410
# fetched_tweetCount : 7505
# fetched_tweetCount : 7600
# fetched_tweetCount : 7695
# fetched_tweetCount : 7790
# fetched_tweetCount : 7885
# fetched_tweetCount : 7980
# fetched_tweetCount : 8075
# fetched_tweetCount : 8170
# fetched_tweetCount : 8265
# fetched_tweetCount : 8360
# fetched_tweetCount : 8455
# fetched_tweetCount : 8550
# fetched_tweetCount : 8645
# fetched_tweetCount : 8740
# fetched_tweetCount : 8835
# fetched_tweetCount : 8930
# fetched_tweetCount : 9025
# fetched_tweetCount : 9120
# fetched_tweetCount : 9215
# fetched_tweetCount : 9310
# fetched_tweetCount : 9405
# fetched_tweetCount : 9500
# fetched_tweetCount : 9595
# fetched_tweetCount : 9690
# fetched_tweetCount : 9785
# fetched_tweetCount : 9880
# fetched_tweetCount : 9975
# fetched_tweetCount : 10070
# fetched_tweetCount : 10165
# fetched_tweetCount : 10260
# fetched_tweetCount : 10355
# fetched_tweetCount : 10450
# fetched_tweetCount : 10545
# fetched_tweetCount : 10640
# fetched_tweetCount : 10735
# fetched_tweetCount : 10830
# fetched_tweetCount : 10925
# fetched_tweetCount : 11020
# fetched_tweetCount : 11115
# fetched_tweetCount : 11210
# fetched_tweetCount : 11305
# fetched_tweetCount : 11400
# fetched_tweetCount : 11495
# fetched_tweetCount : 11590
# fetched_tweetCount : 11685
# fetched_tweetCount : 11780
# fetched_tweetCount : 11875
# fetched_tweetCount : 11970
# fetched_tweetCount : 12065
# fetched_tweetCount : 12160
# fetched_tweetCount : 12255
# fetched_tweetCount : 12350
# fetched_tweetCount : 12445
# fetched_tweetCount : 12540
# fetched_tweetCount : 12635
# fetched_tweetCount : 12730
# fetched_tweetCount : 12825
# fetched_tweetCount : 12920
# fetched_tweetCount : 13015
# fetched_tweetCount : 13110
# fetched_tweetCount : 13205
# fetched_tweetCount : 13300
# fetched_tweetCount : 13395
# fetched_tweetCount : 13490
# fetched_tweetCount : 13585
# fetched_tweetCount : 13680
# fetched_tweetCount : 13775
# fetched_tweetCount : 13870
# fetched_tweetCount : 13965
# fetched_tweetCount : 14060
# fetched_tweetCount : 14155
# fetched_tweetCount : 14250
# fetched_tweetCount : 14345
# fetched_tweetCount : 14440
# fetched_tweetCount : 14535
# fetched_tweetCount : 14630
# fetched_tweetCount : 14725
# fetched_tweetCount : 14820
# fetched_tweetCount : 14915
# fetched_tweetCount : 15010
# Start Date: 2016-02-03
# End Date: 2016-02-04
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# Rate limit reached. Sleeping for: 660
# ERROR - Failed to send request: ('Connection aborted.', error(SysCallError(10054, 'WSAECONNRESET'),))
# Start Date: 2016-02-04
# End Date: 2016-02-05
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-05
# End Date: 2016-02-06
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# Rate limit reached. Sleeping for: 705
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Start Date: 2016-02-06
# End Date: 2016-02-07
# fetched_tweetCount : 100
# fetched_tweetCount : 200
# fetched_tweetCount : 300
# fetched_tweetCount : 400
# fetched_tweetCount : 500
# fetched_tweetCount : 600
# fetched_tweetCount : 700
# fetched_tweetCount : 800
# fetched_tweetCount : 900
# fetched_tweetCount : 1000
# fetched_tweetCount : 1100
# fetched_tweetCount : 1200
# fetched_tweetCount : 1300
# fetched_tweetCount : 1400
# fetched_tweetCount : 1500
# fetched_tweetCount : 1600
# fetched_tweetCount : 1700
# fetched_tweetCount : 1800
# fetched_tweetCount : 1900
# fetched_tweetCount : 2000
# fetched_tweetCount : 2100
# fetched_tweetCount : 2200
# fetched_tweetCount : 2300
# fetched_tweetCount : 2400
# fetched_tweetCount : 2500
# fetched_tweetCount : 2600
# fetched_tweetCount : 2700
# fetched_tweetCount : 2800
# fetched_tweetCount : 2900
# fetched_tweetCount : 3000
# fetched_tweetCount : 3100
# fetched_tweetCount : 3200
# fetched_tweetCount : 3300
# fetched_tweetCount : 3400
# fetched_tweetCount : 3500
# fetched_tweetCount : 3600
# fetched_tweetCount : 3700
# fetched_tweetCount : 3800
# fetched_tweetCount : 3900
# fetched_tweetCount : 4000
# fetched_tweetCount : 4100
# fetched_tweetCount : 4200
# fetched_tweetCount : 4300
# fetched_tweetCount : 4400
# fetched_tweetCount : 4500
# fetched_tweetCount : 4600
# fetched_tweetCount : 4700
# fetched_tweetCount : 4800
# fetched_tweetCount : 4900
# fetched_tweetCount : 5000
# fetched_tweetCount : 5100
# fetched_tweetCount : 5200
# fetched_tweetCount : 5300
# fetched_tweetCount : 5400
# fetched_tweetCount : 5500
# fetched_tweetCount : 5600
# fetched_tweetCount : 5700
# fetched_tweetCount : 5800
# fetched_tweetCount : 5900
# fetched_tweetCount : 6000
# Rate limit reached. Sleeping for: 694
# fetched_tweetCount : 6100
# fetched_tweetCount : 6200
# fetched_tweetCount : 6300
# fetched_tweetCount : 6400
# fetched_tweetCount : 6500
# fetched_tweetCount : 6600
# fetched_tweetCount : 6700
# fetched_tweetCount : 6800
# fetched_tweetCount : 6900
# fetched_tweetCount : 7000
# fetched_tweetCount : 7100
# fetched_tweetCount : 7200
# fetched_tweetCount : 7300
# fetched_tweetCount : 7400
# fetched_tweetCount : 7500
# fetched_tweetCount : 7600
# fetched_tweetCount : 7700
# fetched_tweetCount : 7800
# fetched_tweetCount : 7900
# fetched_tweetCount : 8000
# fetched_tweetCount : 8100
# fetched_tweetCount : 8200
# fetched_tweetCount : 8300
# fetched_tweetCount : 8400
# fetched_tweetCount : 8500
# fetched_tweetCount : 8600
# fetched_tweetCount : 8700
# fetched_tweetCount : 8800
# fetched_tweetCount : 8900
# fetched_tweetCount : 9000
# fetched_tweetCount : 9100
# fetched_tweetCount : 9200
# fetched_tweetCount : 9300
# fetched_tweetCount : 9400
# fetched_tweetCount : 9500
# fetched_tweetCount : 9600
# fetched_tweetCount : 9700
# fetched_tweetCount : 9800
# fetched_tweetCount : 9900
# fetched_tweetCount : 10000
# fetched_tweetCount : 10100
# fetched_tweetCount : 10200
# fetched_tweetCount : 10300
# fetched_tweetCount : 10400
# fetched_tweetCount : 10500
# fetched_tweetCount : 10600
# fetched_tweetCount : 10700
# fetched_tweetCount : 10800
# fetched_tweetCount : 10900
# fetched_tweetCount : 11000
# fetched_tweetCount : 11100
# fetched_tweetCount : 11200
# fetched_tweetCount : 11300
# fetched_tweetCount : 11400
# fetched_tweetCount : 11500
# fetched_tweetCount : 11600
# fetched_tweetCount : 11700
# fetched_tweetCount : 11800
# fetched_tweetCount : 11900
# fetched_tweetCount : 12000
# fetched_tweetCount : 12100
# fetched_tweetCount : 12200
# fetched_tweetCount : 12300
# fetched_tweetCount : 12400
# fetched_tweetCount : 12500
# fetched_tweetCount : 12600
# fetched_tweetCount : 12700
# fetched_tweetCount : 12800
# fetched_tweetCount : 12900
# fetched_tweetCount : 13000
# fetched_tweetCount : 13100
# fetched_tweetCount : 13200
# fetched_tweetCount : 13300
# fetched_tweetCount : 13400
# fetched_tweetCount : 13500
# fetched_tweetCount : 13600
# fetched_tweetCount : 13700
# fetched_tweetCount : 13800
# fetched_tweetCount : 13900
# fetched_tweetCount : 14000
# fetched_tweetCount : 14100
# fetched_tweetCount : 14200
# fetched_tweetCount : 14300
# fetched_tweetCount : 14400
# fetched_tweetCount : 14500
# fetched_tweetCount : 14600
# fetched_tweetCount : 14700
# fetched_tweetCount : 14800
# fetched_tweetCount : 14900
# fetched_tweetCount : 15000
# Total tweets 0
