# %%
import twitter
#import json
# Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'Y8PpyLf5UW0LSCdwTXHXI8Ypn'
CONSUMER_SECRET ='BppAOhd8pLJxchOufdS3TTcv3F4CZptnUUHLtW65vsjv7oaJdl'
OAUTH_TOKEN = '276846978-P2rWU1Dqthv3IRIP3sspbVCyhdmVrVrYqYVuqE1R'
OAUTH_TOKEN_SECRET = 'ToLp2UEfMDIa9U8Z96g7wwjgS0bno1TxZhE8bpuitCO99'

#auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
#                           CONSUMER_KEY, CONSUMER_SECRET)

#twitter_api = twitter.Twitter(auth=auth)

#Necessary imports for tweepy streaming
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import io

#Override listener class for streaming the tweets.
class StdOutListener(StreamListener):
    
    #triggered upon receving a data/tweet
    def on_data(self, data):
        print data
        fname = 'rip_raw_tweets.json'
        #write raw data to json
        dataFile = io.open(fname, 'a', encoding='utf-8')
        tweet_data = []
        tweet_data.append(data)
        dataFile.write(','.join(tweet_data))

    #triggered upon Error
    def on_error(self, status):
        print status


def stream_list_of_keywords(word_list = []):
    #Create an instance of listeniner class
    listen = StdOutListener()

    #OAuth with tweepy wrappers.
    auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

    stream = Stream(auth, listen)
    stream.filter(track=word_list)
    
#Steam  out the tweets with list of keywords.
stream_list_of_keywords(word_list = ["RIP","rest in peace","resa in peace"])
# Out:
# {"created_at":"Sat Feb 06 03:02:15 +0000 2016","id":695804668379680768,"id_str":"695804668379680768","text":"AHAAH HE'S OUR ALLY. RIP MC WHO IS LIKE \"n O nOOO WE ARE NOT WORKING TGH\" jk you are. for the next 80 hours of gameplay","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2916488522,"id_str":"2916488522","name":"cowceratops","screen_name":"nartfarts","location":null,"url":"http:\/\/counterorbit.tumblr.com","description":"rennae's art twitter!! pixivID=194326 Store:http:\/\/rennae.tictail.com","protected":false,"verified":false,"followers_count":191,"friends_count":252,"listed_count":7,"favourites_count":17285,"statuses_count":35899,"created_at":"Tue Dec 02 10:42:26 +0000 2014","utc_offset":-28800,"time_zone":"Pacific Time (US & Canada)","geo_
# ...
