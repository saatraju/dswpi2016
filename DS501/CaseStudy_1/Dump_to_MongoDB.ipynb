# %%
import os

from boto import dynamodb2
from boto.dynamodb2.table import Table


TABLE_NAME = "test"
REGION = "us-west-2"

AWS_ACCESS_KEY_ID = 'AKIAITUXF7HMRPM7J7WA'
AWS_SECRET_ACCESS_KEY = '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'
conn = dynamodb2.connect_to_region(
    REGION,
    aws_access_key_id = AWS_ACCESS_KEY_ID,
    aws_secret_access_key = AWS_SECRET_ACCESS_KEY,
    )
table = Table(
    TABLE_NAME,
    connection=conn
)
# Add new items to  test table


def get_tweets_json():
    import json

    tweets_data_path = 'C:\Users\satish\Desktop\DS-501\\raw_tweets_SB.json'

    tweets_data = []
    RT_tweets = []
    tweets_file = open(tweets_data_path, "r")
    for line in tweets_file:
        tweet = json.loads(line) 
        #print tweet
        #break
        try:
            tweet = json.loads(line)        
            tweets_data.append(tweet)
            #if "retweeted_status" in tweet:
            #    tweets_data.append(tweet)
            #    print tweet
            #    print "retweet count"+str(tweet["retweeted_status"]["retweet_count"])
            #    print "=================================="
        except:
            continue
        #break
    #print "Total Tweet Count : "+str(len(tweets_data[0:5:]) )
    return tweets_data #[0:5:]
    
tweet_list = get_tweets_json()
print "push tweets" + str(len(tweet_list))
legit_data = {}
for t in tweet_list[11:190:]:
    print t["created_at"]
    print t["user"]["screen_name"]
    legit_data["id"] = t["id"]
    legit_data["created_at"] = t["created_at"]
    legit_data["screen_name"] = t["user"]["screen_name"]
    legit_data["user"] = t["user"]
    if"retweeted_status" in t:
        legit_data["retweetedstatus"] = t["retweeted_status"]
    else:
        legit_data["retweetedstatus"] = 'NA'
    legit_data["entities"] = t["entities"]
    legit_data["lang"] = t["lang"]
    print legit_data
    table.put_item(data={
            'tweet_id': str(legit_data["id"]),
            'lang':legit_data["lang"],
            'retweet':legit_data["created_at"],
            'user_data':str(legit_data["user"]),
            'entities':legit_data["entities"],
            'entity':legit_data["entities"],
            'user_screen':legit_data["screen_name"],
     },
                   overwrite=True)
    johndoe = table.get_item(tweet_id=str(legit_data["id"]))
    johndoe.save(overwrite=True)
